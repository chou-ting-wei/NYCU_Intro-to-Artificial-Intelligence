# %% [markdown]
# ngram - without preprocess

# %%
# !python main.py --model_type ngram --preprocess 0 --part 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Progress: 100%|███████████████████████████| 10000/10000 [03:25<00:00, 48.75it/s]
# Perplexity of ngram: 116.26046015880357
# Converting train data to embeddings: 100%|█| 40000/40000 [05:30<00:00, 120.90it/
# Converting test data to embeddings: 100%|█| 10000/10000 [01:23<00:00, 120.31it/s
# F1 score: 0.7051, Precision: 0.7082, Recall: 0.7059

# %% [markdown]
# ngram - with remove stopwords

# %%
# !python main.py --model_type ngram --preprocess 1 --part 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Preprocessing train data: 100%|█████████| 40000/40000 [00:29<00:00, 1361.00it/s]
# Preprocessing test data: 100%|██████████| 10000/10000 [00:07<00:00, 1296.82it/s]
# Progress: 100%|███████████████████████████| 10000/10000 [01:41<00:00, 98.65it/s]
# Perplexity of ngram: 195.43245350997685
# Converting train data to embeddings: 100%|█| 40000/40000 [03:48<00:00, 175.32it/
# Converting test data to embeddings: 100%|█| 10000/10000 [00:56<00:00, 176.74it/s
# F1 score: 0.6745, Precision: 0.6902, Recall: 0.6792

# %% [markdown]
# ngram - with your method

# %%
# !python main.py --model_type ngram --preprocess 1 --part 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/chou.ting.wei/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Preprocessing train data: 100%|██████████| 40000/40000 [01:52<00:00, 354.58it/s]
# Preprocessing test data: 100%|███████████| 10000/10000 [00:24<00:00, 404.87it/s]
# Progress: 100%|██████████████████████████| 10000/10000 [00:21<00:00, 471.84it/s]
# Perplexity of ngram: 309.5762439395389
# Converting train data to embeddings: 100%|█| 40000/40000 [02:52<00:00, 231.58it/
# Converting test data to embeddings: 100%|█| 10000/10000 [00:42<00:00, 233.97it/s
# F1 score: 0.7095, Precision: 0.7187, Recall: 0.7118
